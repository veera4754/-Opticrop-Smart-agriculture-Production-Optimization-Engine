# %%
X=df.drop(['label'],axis=1)

y=df['label']

print(X.shape)
print(y.shape)
# Out:
# (2200, 7)
# (2200,)

# %%
X=df.drop(['label'],axis=1)

y=df['label']

# %%
rainy=df[df['rainfall']>200]

rainy['label'].value_counts()
# Out:
# label
# rice       80
# papaya     26
# coconut    26
# Name: count, dtype: int64

# %%
winter=df[df['temperature']<20]

winter['label'].value_counts()
# Out:
# label
# chickpea       79
# kidneybeans    51
# grapes         41
# orange         36
# pomegranate    30
# maize          27
# pigeonpeas     16
# lentil         11
# Name: count, dtype: int64

# %%
summer=df[df['temperature']>30]

summer['label'].value_counts()
# Out:
# label
# papaya        68
# mango         65
# blackgram     48
# pigeonpeas    40
# mothbeans     27
# grapes        27
# orange        23
# Name: count, dtype: int64

# %%
df['K_log']=np.log1p(df['K'])

# %%
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
sns.histplot(df['K'],kde=True)
plt.title("Original K")

plt.subplot(1,2,2)
sns.histplot(df['K_log'],kde=True)
plt.title("Log Transformed K")

plt.show()

# %%
df['K_log']=np.log1p(df['K'])

# %%
df[['K','K_log']].head()
# Out:
#     K     K_log
# 0  43  3.784190
# 1  41  3.737670
# 2  44  3.806662
# 3  40  3.713572
# 4  42  3.761200

# %%
df['K_log']=np.log1p(df['K'])

# %%
df[['K','K_log']].head()
# Out:
#     K     K_log
# 0  43  3.784190
# 1  41  3.737670
# 2  44  3.806662
# 3  40  3.713572
# 4  42  3.761200

# %%
df['K_log']=np.log1p(df['K'])

# %%
df['K_log']=np.log1p(df['K'])

df[['K','K_log']].head()
# Out:
#     K     K_log
# 0  43  3.784190
# 1  41  3.737670
# 2  44  3.806662
# 3  40  3.713572
# 4  42  3.761200

# %%
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
sns.histplot(df['K'],kde=True)
plt.title("Original K")

plt.subplot(1,2,2)
sns.histplot(df['K_log'],kde=True)
plt.title("Log Transformed K")

plt.show()

# %%
df['K_log']=np.log1p(df['K'])

df[['K','K_log']].head()
# Out:
#     K     K_log
# 0  43  3.784190
# 1  41  3.737670
# 2  44  3.806662
# 3  40  3.713572
# 4  42  3.761200

# %%
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
sns.histplot(df['K'],kde=True)
plt.title("Original K")

plt.subplot(1,2,2)
sns.histplot(df['K_log'],kde=True)
plt.title("Log Transformed K")

plt.show()

# %%
df['K_log']=np.log1p(df['K'])

# %%
outliers=df[(df['K']<lower_bound) | (df['K']>upper_bound)]

print("Number of Outliers:",len(outliers))
outliers.head()
# Out:
# Number of Outliers: 200
#        N    P    K  temperature   humidity        ph   rainfall   label  \
# 1200  24  130  195    29.996772  81.541566  6.112306  67.125345  grapes
# 1201  13  144  204    30.728040  82.426141  6.092242  68.381355  grapes
# 1202  22  123  205    32.445778  83.885049  5.896343  68.739325  grapes
# 1203  36  125  196    37.465668  80.659687  6.155261  66.838723  grapes
# 1204  24  131  196    22.032962  83.743728  5.732454  65.344408  grapes
#
#          K_log
# 1200  5.278115
# 1201  5.323010
# 1202  5.327876
# 1203  5.283204
# 1204  5.283204

# %%
Q1=df['K'].quantile(0.25)
Q3=df['K'].quantile(0.75)

IQR=Q3-Q1

lower_bound=Q1-(1.5*IQR)
upper_bound=Q3+(1.5*IQR)

print("Q1 =",Q1)
print("Q3 =",Q3)
print("IQR =",IQR)
print("Lower Bound =",lower_bound)
print("Upper Bound =",upper_bound)
# Out:
# Q1 = 20.0
# Q3 = 49.0
# IQR = 29.0
# Lower Bound = -23.5
# Upper Bound = 92.5

# %%
sns.boxplot(x=df['K'])
plt.title("Potassium Distribution")
plt.show()

# %%
df.isnull().sum()
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# K_log          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            2200 non-null   int64
#  1   P            2200 non-null   int64
#  2   K            2200 non-null   int64
#  3   temperature  2200 non-null   float64
#  4   humidity     2200 non-null   float64
#  5   ph           2200 non-null   float64
#  6   rainfall     2200 non-null   float64
#  7   label        2200 non-null   str
#  8   K_log        2200 non-null   float64
# dtypes: float64(5), int64(3), str(1)
# memory usage: 154.8 KB

# %%
df.shape
# Out:
# (2200, 9)

# %%
df.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label     K_log
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice  3.784190
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice  3.737670
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice  3.806662
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice  3.713572
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice  3.761200

# %%
df=pd.read_csv("dataset/Crop_recommendation.csv")

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('fivethirtyeight')

print("Libraries Imported Successfully")
# Out:
# Libraries Imported Successfully
